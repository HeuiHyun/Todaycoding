# %% [markdown]
# ### 1 서울시에서 공개한 코로나 19 발생동향 분석
# https://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
# 필요한 라이브러리를 불러옵니다.
import pandas as pd
import numpy as np

# %%
# 크롤링으로 가져올 url 주소를 입력합니다.
url='https://www.seoul.go.kr/coronaV/coronaStatus.do'
url
# Out:
# 'https://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
# 11월 중순 이후 확진자가 증가하면서 데이터 공개 방식이 달라져서 pandas의 read_html로는 불러올 수가 없습니다.
# 기존의 read_html로는 컬럼명을 불러오고 데이터는 request라는 라이브러리를 통해 읽어옵니다.

# %%
# 판다스의 read_html 을 통해 url에 있는 데이터를 불러옵니다.
table = pd.read_html(url)
len(table)
# Out:
# 6

# %%
# read_html은 사이트 내의 html 태그를 불러옵니다.
df=table[4]
df
# Out:
# Empty DataFrame
# Columns: [연번, 환자, 확진일, 거주지, 여행력, 접촉력, 퇴원현황]
# Index: []

# %%
# table 변수 안에 있는 table 태그의 값을 하나씩 읽어보며 확진자 목록이 있는 테이블을 가져옵니다.
table[1]
# Out:
#      종로구    중구   용산구   성동구  광진구  동대문구
# 0    435   290   429   478  480   678
# 1     +5    +2     0    +8  +11    +6
# 2    중랑구   성북구   강북구   도봉구  노원구   은평구
# 3    828   843   488   591  848   806
# 4    +14   +10   +14   +10  +11    +3
# 5   서대문구   마포구   양천구   강서구  구로구   금천구
# 6    530   717   757  1391  649   332
# 7     +2    +8    +9   +15   +7    +5
# 8   영등포구   동작구   관악구   서초구  강남구   송파구
# 9    730   862  1049   846  953  1153
# 10   +14   +10    +7    +4  +11    +8
# 11   강동구    기타   NaN   NaN  NaN   NaN
# 12   600  2375   NaN   NaN  NaN   NaN
# 13    +7  +128   NaN   NaN  NaN   NaN

# %% [markdown]
# ### 11월 중순 이후 데이터 공개방식 변경

# %%
import requests

# %%
# f-string
url= "https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php?draw=1"
url= f"{url}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable"
url= f"{url}%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D="
url= f"{url}&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc&start=0&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1609783543791"
url
# Out:
# 'https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php?draw=1&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true
# ...

# %%
response=requests.get(url)
data_json=response.json()
pd.DataFrame(data_json["data"]) # 판다스 데이터프레임으로 불러줄 수 있다.
# Out:
#                                    0      1          2    3  4  \
# 0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
# 1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
# 2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
# 3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
# 4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
# ..                               ...    ...        ...  ... ..
# 95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
# 96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
# 97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
# 98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
# 99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉    <b class='status1'></b>
# 2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
records_total = data_json['recordsTotal']
records_total
# Out:
# 10000

# %%
end_page = round(records_total/100)+1
end_page
# Out:
# 101

# %%
data=data_json["data"]

# %%
data
# Out:
# [["<p class='corona19_no'>10000</p>",
#   '37131',
#   '20.12.05.',
#   '금천구',
#   '-',
#   '구로구 소재 보험회사 관련',
#   "<b class='status1'>퇴원</b>"],
#  ["<p class='corona19_no'>9999</p>",
#   '37141',
#   '20.12.05.',
#   '금천구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status1'></b>"],
#  ["<p class='corona19_no'>9998</p>",
#   '37541',
#   '20.12.05.',
#   '송파구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status1'></b>"],
#  ["<p class='corona19_no'>9997</p>",
#   '37542',
#   '20.12.05.',
#   '송파구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status1'></b>"],
#  ["<p class='corona19_no'>9996</p>",
#   '37087',
#   '20.12.05.',
#   '서초구',
#   '-',
#   '기타 확진자 접촉',
#   "<b class='status1'>퇴원</b>"],
#  ["<p class='corona19_no'>9995</p>",
#   '37073',
#   '20.12.05.',
#   '서초구',
#   '-',
#   '동작구 최비야 관련',
#   "<b class='status1'>퇴원</b>"],
#  ["<p class='corona19_no'>9994</p>",
#   '37072',
#   '20.12.05.',
#   '서초구',
#   '-',
#   '감염경로 조사중',
#   "<b class='status1'>퇴원</b>"],
# ...

# %%
pd.DataFrame(data)
# Out:
#                                    0      1          2    3  4  \
# 0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
# 1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
# 2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
# 3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
# 4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
# ..                               ...    ...        ...  ... ..
# 95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
# 96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
# 97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
# 98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
# 99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉    <b class='status1'></b>
# 2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %% [markdown]
# # 함수로 만들기

# %%
def get_seoul_covid19_100(page_no):
    """
    page_no : 입력값으로 페이지 번호를 입력하면 해당 번호의 데이터를 가져옴
    start_no : 입력받은 page_no로 시작 번호를 의미
    """
    start_no =(page_no-1)*100
    url= "https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php?draw=1"
    url= f"{url}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable"
    url= f"{url}%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D="
    url= f"{url}&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc&start=0&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1609783543791"
    response=requests.get(url)
    data_json=response.json()
    return data_json

# %%
# 데이터가 있을 때
get_seoul_covid19_100(3)
# Out:
# {'draw': 1,
#  'recordsTotal': 10000,
#  'recordsFiltered': 10000,
#  'data': [["<p class='corona19_no'>10000</p>",
#    '37131',
#    '20.12.05.',
#    '금천구',
#    '-',
#    '구로구 소재 보험회사 관련',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9999</p>",
#    '37141',
#    '20.12.05.',
#    '금천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'></b>"],
#   ["<p class='corona19_no'>9998</p>",
#    '37541',
#    '20.12.05.',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'></b>"],
#   ["<p class='corona19_no'>9997</p>",
#    '37542',
#    '20.12.05.',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'></b>"],
#   ["<p class='corona19_no'>9996</p>",
#    '37087',
#    '20.12.05.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9995</p>",
#    '37073',
#    '20.12.05.',
#    '서초구',
#    '-',
#    '동작구 최비야 관련',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9994</p>",
# ...

# %%
# 데이터가 없을 때
get_seoul_covid19_100(-1)
# Out:
# {'draw': 1,
#  'recordsTotal': 10000,
#  'recordsFiltered': 10000,
#  'data': [["<p class='corona19_no'>10000</p>",
#    '37131',
#    '20.12.05.',
#    '금천구',
#    '-',
#    '구로구 소재 보험회사 관련',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9999</p>",
#    '37141',
#    '20.12.05.',
#    '금천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'></b>"],
#   ["<p class='corona19_no'>9998</p>",
#    '37541',
#    '20.12.05.',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'></b>"],
#   ["<p class='corona19_no'>9997</p>",
#    '37542',
#    '20.12.05.',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'></b>"],
#   ["<p class='corona19_no'>9996</p>",
#    '37087',
#    '20.12.05.',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9995</p>",
#    '37073',
#    '20.12.05.',
#    '서초구',
#    '-',
#    '동작구 최비야 관련',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9994</p>",
# ...

# %% [markdown]
# ## 전체 데이터 가져오기

# %%
# time.sleep 으로 시차를 두기 위해
import time
# tqdm : 진행상태를 표시하기 위해
from tqdm import trange

# %%
# page_list = []
# for page_no in trange(500,503):
#     one_page = get_seoul_covid19_100(page_no)
#     if len(one_page["data"])>0:                   # 없는 페이지의 경우 빠져 나와라라는 조건문
#         one_page = pd.DataFrame(one_page["data"])
#         page_list.append(one_page)
#         time.sleep(0.5) 
#     else:
#         break
# Out:
# 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]

# %%
one_page
# Out:
#                                    0      1          2    3  4  \
# 0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
# 1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
# 2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
# 3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
# 4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
# ..                               ...    ...        ...  ... ..
# 95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
# 96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
# 97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
# 98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
# 99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉    <b class='status1'></b>
# 2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
page_list
# Out:
# [                                   0      1          2    3  4  \
#  0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
#  1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
#  2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
#  3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
#  4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
#  ..                               ...    ...        ...  ... ..
#  95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
#  96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
#  97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
#  98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
#  99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                   5                          6
#  0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
#  1        기타 확진자 접촉    <b class='status1'></b>
#  2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
pd.concat(page_list) # pd.concat은 여러개의 데이터프레임을 하나로 합칠때 사용
# Out:
#                                    0      1          2    3  4  \
# 0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
# 1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
# 2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
# 3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
# 4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
# ..                               ...    ...        ...  ... ..
# 95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
# 96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
# 97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
# 98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
# 99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉    <b class='status1'></b>
# 2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
# 전체 페이지를 가져오기 전에 일부 페이지만 실행
page_list = []
# 데이터가 제대로 로드 되는지 앞부분 3페이지 정도만 확인하고 전체페이지를 가져오도록 합니다.
# 처음부터 전체 페이즈를 수집하면 중간에 오류가 나도 찾기가 어렵습니다.
# 일부만 우선 가져와 보고 잘 동작한다면 전체를 가져오도록 합니다.
all_page =3 
for page_no in trange(all_page + 1):
    one_page = get_seoul_covid19_100(page_no)
    one_page = pd.DataFrame(one_page["data"])
    page_list.append(one_page)
    # 서버에 한번에 너무 많은요청을 보내면 서버에 부담이 됩니다.
    # 서버에 부담을 주지 않기 위해 0.5초씩 쉬었다 가져온다.
    time.sleep(0.5)
# Out:
# 100%|██████████| 4/4 [00:02<00:00,  1.82it/s]

# %%
# 가져온 데이터가 맞는지 확인 너무 많을 수 있기 때문에 슬라이싱으로 잘라서 보기
pd.concat(page_list)
# Out:
#                                    0      1          2    3  4  \
# 0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
# 1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
# 2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
# 3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
# 4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
# ..                               ...    ...        ...  ... ..
# 95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
# 96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
# 97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
# 98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
# 99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉    <b class='status1'></b>
# 2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
def get_multi_page_list(start_page,end_page = 80):
    # 데이터가 제대로 로드 되는지 앞부분 3페이지 정도만 확인하고 전체페이지를 가져오도록 합니다.
   
    page_list = []
    for page_no in trange(start_page,end_page+1):
        one_page = get_seoul_covid19_100(page_no)
        if len(one_page["data"])>0:                   
            one_page = pd.DataFrame(one_page["data"])
            page_list.append(one_page)
            time.sleep(0.5) 
        else:
            # 수집된 값이 없다면 False를 반환합니다.
            # False 반환 시 수집한 리스트를 반환하도록 합니다.
            return page_list
    return page_list

# %% [markdown]
# #### 시작페이지와 끝페이지를 꼭 확인해 주세요.

# %%
# 따로 설정하지 않으면 end_page 변수에 들어있는 숫자가 마짐가 페이지가 됩니다.
end_page
# Out:
# 3

# %%
# 시작페이지와 끝페이지를 꼭 확인해 주세요.
start_page=1
end_page=4
page_list=get_multi_page_list(start_page,end_page)
#데이터가 너무 많기 때문에 슬라이싱으로 1개만 미리보기
page_list[:1]
# Out:
# 100%|██████████| 4/4 [00:02<00:00,  1.50it/s]
# [                                   0      1          2    3  4  \
#  0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
#  1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
#  2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
#  3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
#  4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
#  ..                               ...    ...        ...  ... ..
#  95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
#  96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
#  97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
#  98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
#  99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                   5                          6
#  0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
#  1        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
page_list
# Out:
# [                                   0      1          2    3  4  \
#  0   <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구  -
#  1    <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구  -
#  2    <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구  -
#  3    <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구  -
#  4    <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구  -
#  ..                               ...    ...        ...  ... ..
#  95   <p class='corona19_no'>9905</p>  36753  20.12.04.  강남구  -
#  96   <p class='corona19_no'>9904</p>  36734  20.12.04.  성동구  -
#  97   <p class='corona19_no'>9903</p>  36732  20.12.04.  서초구  -
#  98   <p class='corona19_no'>9902</p>  36751  20.12.04.  서초구  -
#  99   <p class='corona19_no'>9901</p>  36727  20.12.04.  은평구  -
#
#                   5                          6
#  0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
#  1        기타 확진자 접촉    <b class='status1'></b>
#  2        기타 확진자 접촉    <b class='status1'></b>
# ...

# %%
# concat을 통해 하나의 데이터프레임으로 합쳐줍니다.
df_all = pd.concat(page_list)
df_all.shape
# Out:
# (400, 7)

# %%
df
# Out:
# Empty DataFrame
# Columns: [연번, 환자, 확진일, 거주지, 여행력, 접촉력, 퇴원현황]
# Index: []

# %%
# read_html로 읽어온 3번째 테이블의 컬럼명을 수집한 데이터의 컬럼으로 사용합니다.
cols = df.columns.tolist()

# %%
df_all.columns = cols

# %%
df_all.head()
# Out:
#                                  연번     환자        확진일  거주지 여행력  \
# 0  <p class='corona19_no'>10000</p>  37131  20.12.05.  금천구   -
# 1   <p class='corona19_no'>9999</p>  37141  20.12.05.  금천구   -
# 2   <p class='corona19_no'>9998</p>  37541  20.12.05.  송파구   -
# 3   <p class='corona19_no'>9997</p>  37542  20.12.05.  송파구   -
# 4   <p class='corona19_no'>9996</p>  37087  20.12.05.  서초구   -
#
#               접촉력                       퇴원현황
# 0  구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1       기타 확진자 접촉    <b class='status1'></b>
# 2       기타 확진자 접촉    <b class='status1'></b>
# 3       기타 확진자 접촉    <b class='status1'></b>
# 4       기타 확진자 접촉  <b class='status1'>퇴원</b>

# %% [markdown]
# # 데이터 전처리
# - 연번과 퇴원현황

# %%
import re # 정규표현식
def extract_number(num_string):
    if type(num_string)==str:
        num_string = num_string.replace("corona19","")
        num = re.sub("[^0-9]","",num_string) # ^0-9 = 숫자가 아니라면 "" = 공백으로 치환 데이터는 num_string
        num=int(num)                         # 전처리 과정
        return num
    else:
        return num_string

# %%
num_string = "<p class='corona19_no'>7625</p>" 
extract_number(num_string)
# Out:
# 7625

# %%
df_all["연번"] = df_all["연번"].map(extract_number)

# %%
df_all["연번"].head()
# Out:
# 0    10000
# 1     9999
# 2     9998
# 3     9997
# 4     9996
# Name: 연번, dtype: int64

# %%
def extract_hangeul(origin_text):
    subtract_text=re.sub("[^가-힣]","",origin_text) # 한글이 아니면 ""으로 치완을 해라
    return subtract_text

# %%
extract_hangeul("<b class='status'>퇴원</b>")
# Out:
# '퇴원'

# %%
extract_hangeul("<b class='status2'>사망</b>")
# Out:
# '사망'

# %%
extract_hangeul("<b class=''></b>")
# Out:
# ''

# %%
# 정규표현식으로 변경하는 방법도 있고 str.contains를 사용하는 방법도 있습니다.
# df_all["퇴원현황"]= df_all["퇴원현황"].mao(extract_hangeul)
# df_all["퇴원현황"].value_counts()

# %%
df_all["퇴원현황"].value_counts()
# Out:
# <b class='status1'>퇴원</b>    240
# <b class='status1'></b>      152
# <b class='status2'>사망</b>      8
# Name: 퇴원현황, dtype: int64

# %%
df_all.loc[df_all["퇴원현황"].str.contains("퇴원"),"퇴원현황"]= "퇴원"
df_all.loc[df_all["퇴원현황"].str.contains("사망"),"퇴원현황"]= "사망"
df_all.loc[~df_all["퇴원현황"].str.contains("퇴원|사망"),"퇴원현황"]= "" # ~ 는 아니라는 의미
df_all["퇴원현황"].value_counts()
# Out:
# 퇴원    240
#       152
# 사망      8
# Name: 퇴원현황, dtype: int64

# %%
last_date = df_all.iloc[0]["확진일"]

# %%
# 마지막 확진일을 파일명에 써주기 위해 . 을 _ 로 변경합니다,
# 확장자와 구분이 쉽게 되도록 _ 로 변경합니다.

date = last_date.replace(".","_")
date
# Out:
# '20_12_05_'

# %%
# 파일명을 만들어 줍니다.
# file_name

file_name = f"seoul-covid19-{date}.csv"
file_name
# Out:
# 'seoul-covid19-20_12_05_.csv'

# %%
# csv 파일로 저장합니다.
df_all.to_csv(file_name, index=False)

# %%
# 제대로 저장되었는지 확인합니다.
pd.read_csv(file_name)
# Out:
#         연번     환자        확진일  거주지 여행력             접촉력 퇴원현황
# 0    10000  37131  20.12.05.  금천구   -  구로구 소재 보험회사 관련   퇴원
# 1     9999  37141  20.12.05.  금천구   -       기타 확진자 접촉  NaN
# 2     9998  37541  20.12.05.  송파구   -       기타 확진자 접촉  NaN
# 3     9997  37542  20.12.05.  송파구   -       기타 확진자 접촉  NaN
# 4     9996  37087  20.12.05.  서초구   -       기타 확진자 접촉   퇴원
# ..     ...    ...        ...  ...  ..             ...  ...
# 395   9905  36753  20.12.04.  강남구   -     강남구 소재 요양병원   퇴원
# 396   9904  36734  20.12.04.  성동구   -     강남구 소재 요양병원   퇴원
# 397   9903  36732  20.12.04.  서초구   -      동작구 사우나 관련   퇴원
# 398   9902  36751  20.12.04.  서초구   -     강남구 소재 요양병원   퇴원
# 399   9901  36727  20.12.04.  은평구   -       기타 확진자 접촉   퇴원
#
# [400 rows x 7 columns]
